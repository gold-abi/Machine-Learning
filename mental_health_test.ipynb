# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
health=pd.read_csv('/content/mental_health_dataset.csv')

# %%
health.head(10)
# Out:
#    age      gender employment_status work_environment mental_health_history  \
# 0   56        Male          Employed          On-site                   Yes
# 1   46      Female           Student          On-site                    No
# 2   32      Female          Employed          On-site                   Yes
# 3   60  Non-binary     Self-employed          On-site                    No
# 4   25      Female     Self-employed          On-site                   Yes
# 5   38      Female        Unemployed          On-site                   Yes
# 6   56  Non-binary          Employed           Remote                    No
# 7   36        Male           Student           Remote                    No
# 8   40        Male          Employed           Hybrid                    No
# 9   28      Female          Employed           Remote                    No
#
#   seeks_treatment  stress_level  sleep_hours  physical_activity_days  \
# ...

# %%
health.isnull().sum()
# Out:
# age                       0
# gender                    0
# employment_status         0
# work_environment          0
# mental_health_history     0
# seeks_treatment           0
# stress_level              0
# sleep_hours               0
# physical_activity_days    0
# depression_score          0
# anxiety_score             0
# social_support_score      0
# productivity_score        0
# mental_health_risk        0
# dtype: int64

# %%
LR=LinearRegression()
le=LabelEncoder()
health['gen']=le.fit_transform(health['gender'])

# %%
le1=LabelEncoder()
health['status']=le1.fit_transform(health['employment_status'])

# %%
le2=LabelEncoder()
health['env']=le2.fit_transform(health['work_environment'])

# %%
le3=LabelEncoder()
health['history']=le3.fit_transform(health['mental_health_history'])

# %%
le4=LabelEncoder()
health['treat']=le4.fit_transform(health['seeks_treatment'])

# %%
le5=LabelEncoder()
health['status']=le5.fit_transform(health['employment_status'])

# %%
le6 = LabelEncoder()
health['risk'] = le6.fit_transform(health['mental_health_risk'])

# %%
health.head()
# Out:
#    age      gender employment_status work_environment mental_health_history  \
# 0   56        Male          Employed          On-site                   Yes
# 1   46      Female           Student          On-site                    No
# 2   32      Female          Employed          On-site                   Yes
# 3   60  Non-binary     Self-employed          On-site                    No
# 4   25      Female     Self-employed          On-site                   Yes
#
#   seeks_treatment  stress_level  sleep_hours  physical_activity_days  \
# 0             Yes             6          6.2                       3
# 1             Yes            10          9.0                       4
# 2              No             7          7.7                       2
# 3              No             4          4.5                       4
# 4             Yes             3          5.4                       0
#
#    depression_score  anxiety_score  social_support_score  productivity_score  \
# ...

# %%
a=health[['age','gen','status','env','history','treat','stress_level','sleep_hours','physical_activity_days','depression_score','anxiety_score','social_support_score','productivity_score']]
b=health['risk']

# %%
LR.fit(a,b)
# Out:
# LinearRegression()

# %%
LR.predict([[21,1,1,1,1,1,8,5,2,24,12,80,70]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.02206448])
